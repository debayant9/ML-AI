# %% [markdown]
# ### Cab-Driver Agent

# %%
# Importing libraries
import numpy as np
import random
import math
from collections import deque
import collections
import os
import pickle

# for building DQN model
from keras import layers
from keras import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam
from keras.models import load_model

# for plotting graphs
import matplotlib.pyplot as plt

# Import the environment
from Env import CabDriver
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Defining Time Matrix

# %%
# Loading the time matrix provided
Time_matrix = np.load("TM.npy")

# %%
States_track = collections.defaultdict(dict)
print(len(States_track))
# Out:
# 0

# %% [markdown]
# #### Tracking the state-action pairs for checking convergence

# %%
# make directory
if not os.path.exists("saved_pickle_files"):
    os.mkdir("saved_pickle_files")

# %%
#This function will initialise the 7 Q-values which need to be tracked for checking convergence

#iters = []                            #the x-axis of convergence graphs

def initialise_tracking_states():
    sample_q_values = [((1,9,1),(1,2)),((1,11,3),(1,3)),((1,20,5),(2,4)),((4,10,5),(3,1)),((3,13,0),(3,1)),((0,9,6),(1,3))]    #select any 4 Q-values
    for q_values in sample_q_values:
        state = q_values[0]
        action = q_values[1]
        States_track[state][action] = []    #this is an array which will have appended values of that state-action pair for every 2000th episode

# %%
#This function will append latest Q-values of the 6 Q-values which are being tracked for checking convergence

def save_tracking_states(actions_list, qvalues, state):
    if state in States_track.keys():
        action = list(States_track[state].keys())
        ind = actions_list.index(action[0])
        qv = qvalues[0][ind]
        States_track[state][action[0]].append(qv)

# %%
#Defining a function to save the Q-dictionary as a pickle file
def save_pickle(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Agent Class
#
# If you are using this framework, you need to fill the following to complete the following code block:
# 1. State and Action Size
# 2. Hyperparameters
# 3. Create a neural-network model in function 'build_model()'
# 4. Define epsilon-greedy strategy in function 'get_action()'
# 5. Complete the function 'append_sample()'. This function appends the recent experience tuple <state, action, reward, new-state> to the memory
# 6. Complete the 'train_model()' function with following logic:
#    - If the memory size is greater than mini-batch size, you randomly sample experiences from memory as per the mini-batch size and do the following:
#       - Initialise your input and output batch for training the model
#       - Calculate the target Q value for each sample: reward + gamma*max(Q(s'a,))
#       - Get Q(s', a) values from the last trained model
#       - Update the input batch as your encoded state and output batch as your Q-values
#       - Then fit your DQN model using the updated input and output batch.

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        # Define size of state and action
        self.input_size = state_size   # input for NN which is size of state + size of action
        self.output_size = action_size # output of NN which is 

        # Write here: Specify you hyper parameters for the DQN
        self.discount_factor = 0.95
        self.learning_rate =  0.01     
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.batch_size = 32 
        self.epsilon_decay = -0.0005
        
        self.batch_size = 32        
        # create replay memory using deque
        self.memory = deque(maxlen=2000)
        
        self.special_states_tracked = []
        
         # We are going to track state [0,0,0] and action (0,2) at index 2 in the action space.
        self.track_state = np.array(env.state_encod_arch1([0,0,0])).reshape(1, 36)

        # create main model and target model
        self.model = self.build_model()

    # approximate Q function using Neural Network
    def build_model(self):
        model = Sequential()
        # Write your code here: Add layers to your neural nets     
        
        # hidden layers
        model.add(Dense(32, input_dim=self.input_size, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))

        # the output layer: output is of size num_actions
        model.add(Dense(self.output_size, activation='relu', kernel_initializer='he_uniform'))

        model.compile(loss='mse',optimizer=Adam(lr=self.learning_rate))
        model.summary
        return model



    def get_action(self, state, env):
    # Write your code here:
    # get action from model using epsilon-greedy policy
    # Decay in ε after we generate each sample from the environment 
        action_index, all_actions = env.requests(state)
#          print(all_actions)
        if np.random.rand() <= self.epsilon:
            # explore: choose a random action from all possible actions
            # in case of cartpole this will randomly choose an action between 0 and 1
            return random.choice(action_index)
        else:
            # choose the action with the highest q(s, a)
            # the first index corresponds to the batch size, so
            # reshape state to (1, state_size) so that the first index corresponds to the batch size
            action_dict = {}
            input_nn = env.state_encod_arch1(state)
            input_nn = input_nn.reshape(1, self.input_size)
            q_value = self.model.predict(input_nn)
            save_tracking_states(env.action_space, q_value, state)
            for ind in action_index:
                action_dict[ind] = q_value[0][ind]
            max_qvalue_action = max(action_dict, key=action_dict.get)
            return max_qvalue_action
        

    def append_sample(self, state, action, reward, next_state, done):
    # Write your code here:
    # save sample <s,a,r,s'> to the replay memory
     self.memory.append((state, action, reward, next_state, done))
    
    
    
    # pick samples randomly from replay memory (with batch_size) and train the network
    def train_model(self):
        
        if len(self.memory) > self.batch_size:
            # Sample batch from the memory
            mini_batch = random.sample(self.memory, self.batch_size)
            update_output = np.zeros((self.batch_size, self.input_size))
            update_input =np.zeros((self.batch_size, self.input_size))
            
            actions, rewards, done = [], [], []
            
            for i in range(self.batch_size):
                state, action, reward, next_state, done_boolean = mini_batch[i]
                state_input_nn = env.state_encod_arch1(state)
                state_input_nn = state_input_nn.reshape(1, self.input_size)
                update_input[i] = state_input_nn
                actions.append(action)
                rewards.append(reward)
                next_state_input_nn = env.state_encod_arch1(state)
                next_state_input_nn = next_state_input_nn.reshape(1, self.input_size)
                update_output[i] = next_state_input_nn
                done.append(done_boolean)
                
                # Write your code from here
                # 1. Predict the target from earlier model
            target = self.model.predict(update_input)
                
                # 2. Get the target for the Q-network
            target_qval = self.model.predict(update_output)
                
                #3. Update your 'update_output' and 'update_input' batch
            for i in range(self.batch_size):
                if done[i]:
                    target[i][actions[i]] = rewards[i]
                else: # non-terminal state
                    #print("thu")
                    target[i][actions[i]] = rewards[i] + self.discount_factor * np.max(target_qval[i])
                
        # 4. Fit your model and track the loss values
            self.model.fit(update_input, target, batch_size=self.batch_size, epochs=1, verbose=0)
            
    def save_tracking_states(self):
        # Use the model to predict the q_value of the state we are tacking.
        q_value = self.model.predict(self.track_state)
        
        # Grab the q_value of the action index that we are tracking.
        self.special_states_tracked.append(q_value[0][2])
            

    def save(self, name):
        with open(name, 'wb') as file:  
            pickle.dump(self.model, file,pickle.HIGHEST_PROTOCOL)

# %%
# Invoke Env class
env = CabDriver()
Episodes = 12000
Save_Rewards_After_Ep = 50
Save_Weights_After_Ep = 50
rewards_per_episode, episodes = [], []
agent = DQNAgent(36,21)
initialise_tracking_states()

# %%
#agent.load_weights("model_weights")

# %%
# Episodes = 5
# agent = DQNAgent(36,21)

# %%
# agent.model.load_weights("model_weights")

# %% [markdown]
# ### DQN block

# %%
for episode in range(Episodes):

    # Write code here
    # Call the environment
    # Call all the initialised variables of the environment
    env = CabDriver()
    all_actions, all_state, curr_state = env.reset()
    terminal_state = False
    revenue = 0
    #Call the DQN agent
    ep_start_hour = curr_state[1]
    ep_end_hour = curr_state[1] + 24 * 30
    #print("ep {0}".format(episode))
    
    while terminal_state == False:
        
        # Write your code here
        # 1. Pick epsilon-greedy action from possible actions for the current state
        # 2. Evaluate your reward and next state
        # 3. Append the experience to the memory
        # 4. Train the model by calling function agent.train_model
        # 5. Keep a track of rewards, Q-values, loss
        fin_action_index = agent.get_action(curr_state, env)
        
        
        
#         if fin_action_index == 20:
#             print("state = {0} {1} {2}, action = {3}".format(curr_state[0],curr_state[1],curr_state[2], fin_action_index))
#         else:
#             act = env.action_space[fin_action_index]
#             print("state = {0} {1} {2}, action = {3} {4}".format(curr_state[0],curr_state[1],curr_state[2],act[0],act[1]))
            
            
        next_state, reward, total_hours_lapsed = env.step(curr_state, fin_action_index, Time_matrix)
        ep_start_hour += total_hours_lapsed
            
        if ep_start_hour >= ep_end_hour:
            terminal_state = True
            
        agent.append_sample(curr_state, fin_action_index, reward, next_state, terminal_state)
        
        agent.train_model()
        revenue += reward
        #print("reward = {0}".format(reward)) 
        curr_state = next_state

    # store total reward obtained in this episode
    rewards_per_episode.append(revenue)
    episodes.append(episode) 
    
    # epsilon decay
    agent.epsilon = (1 - 0.00001) * np.exp(agent.epsilon_decay * episode)

    # save rewards_per_episode
    if episode % Save_Rewards_After_Ep == 0: 
        save_pickle(rewards_per_episode, "saved_pickle_files/rewards_per_episode")
    
    if episode % Save_Rewards_After_Ep == 0:     
        save_pickle(States_track,'saved_pickle_files/States_tracked') 
        
    if ((episode + 1) % 5 == 0):
        print("reward after ep {0} = {1}".format(episode, revenue))
        agent.save_tracking_states()
        
        
    if(episode % Save_Weights_After_Ep == 0):
        print("Saving Model {}".format(episode))
        agent.save(name="model_weights.pkl")
# Out:
# Saving Model 0
# reward after ep 4 = -68.0
# reward after ep 9 = -244.0
# reward after ep 14 = -222.0
# reward after ep 19 = -241.0
# reward after ep 24 = -248.0
# reward after ep 29 = -298.0
# reward after ep 34 = 52.0
# reward after ep 39 = 9.0
# reward after ep 44 = -344.0
# reward after ep 49 = -105.0
# Saving Model 50
# reward after ep 54 = -335.0
# reward after ep 59 = -117.0
# reward after ep 64 = 111.0
# reward after ep 69 = -297.0
# reward after ep 74 = 88.0
# reward after ep 79 = -61.0
# reward after ep 84 = 36.0
# reward after ep 89 = 130.0
# reward after ep 94 = -312.0
# reward after ep 99 = -181.0
# Saving Model 100
# reward after ep 104 = -167.0
# reward after ep 109 = -498.0
# reward after ep 114 = 228.0
# reward after ep 119 = -194.0
# reward after ep 124 = 108.0
# reward after ep 129 = -400.0
# reward after ep 134 = -216.0
# reward after ep 139 = -172.0
# reward after ep 144 = -90.0
# reward after ep 149 = 36.0
# Saving Model 150
# reward after ep 154 = 73.0
# reward after ep 159 = 117.0
# reward after ep 164 = -279.0
# reward after ep 169 = -13.0
# reward after ep 174 = 94.0
# reward after ep 179 = 415.0
# reward after ep 184 = 108.0
# reward after ep 189 = 161.0
# reward after ep 194 = 171.0
# reward after ep 199 = 159.0
# Saving Model 200
# reward after ep 204 = -217.0
# reward after ep 209 = -130.0
# reward after ep 214 = -144.0
# reward after ep 219 = 110.0
# reward after ep 224 = -222.0
# reward after ep 229 = 60.0
# reward after ep 234 = 80.0
# reward after ep 239 = -54.0
# reward after ep 244 = -207.0
# reward after ep 249 = -7.0
# Saving Model 250
# reward after ep 254 = -37.0
# reward after ep 259 = 35.0
# reward after ep 264 = -298.0
# reward after ep 269 = -108.0
# reward after ep 274 = -148.0
# reward after ep 279 = -184.0
# reward after ep 284 = 75.0
# reward after ep 289 = -127.0
# reward after ep 294 = -42.0
# reward after ep 299 = 71.0
# Saving Model 300
# reward after ep 304 = 63.0
# reward after ep 309 = 324.0
# reward after ep 314 = -62.0
# reward after ep 319 = 27.0
# reward after ep 324 = 18.0
# reward after ep 329 = 121.0
# reward after ep 334 = 129.0
# reward after ep 339 = 135.0
# reward after ep 344 = -405.0
# reward after ep 349 = 127.0
# Saving Model 350
# reward after ep 354 = -33.0
# reward after ep 359 = -60.0
# reward after ep 364 = 109.0
# reward after ep 369 = 242.0
# reward after ep 374 = -180.0
# reward after ep 379 = -99.0
# reward after ep 384 = 134.0
# reward after ep 389 = 99.0
# reward after ep 394 = 117.0
# reward after ep 399 = 54.0
# Saving Model 400
# reward after ep 404 = -55.0
# reward after ep 409 = 37.0
# reward after ep 414 = 180.0
# reward after ep 419 = 102.0
# reward after ep 424 = 145.0
# reward after ep 429 = -132.0
# reward after ep 434 = -115.0
# reward after ep 439 = 153.0
# reward after ep 444 = 108.0
# reward after ep 449 = 297.0
# Saving Model 450
# reward after ep 454 = -60.0
# reward after ep 459 = 3.0
# reward after ep 464 = 46.0
# reward after ep 469 = 11.0
# reward after ep 474 = 174.0
# reward after ep 479 = 166.0
# reward after ep 484 = 170.0
# reward after ep 489 = 23.0
# reward after ep 494 = 2.0
# reward after ep 499 = 245.0
# Saving Model 500
# reward after ep 504 = -240.0
# reward after ep 509 = 63.0
# reward after ep 514 = -206.0
# reward after ep 519 = 389.0
# reward after ep 524 = 105.0
# reward after ep 529 = -70.0
# reward after ep 534 = 18.0
# reward after ep 539 = 35.0
# reward after ep 544 = 270.0
# reward after ep 549 = 84.0
# Saving Model 550
# reward after ep 554 = 159.0
# reward after ep 559 = -96.0
# reward after ep 564 = 129.0
# reward after ep 569 = -24.0
# reward after ep 574 = 196.0
# reward after ep 579 = 257.0
# reward after ep 584 = 381.0
# reward after ep 589 = 118.0
# reward after ep 594 = -36.0
# reward after ep 599 = 129.0
# Saving Model 600
# reward after ep 604 = 178.0
# reward after ep 609 = -10.0
# reward after ep 614 = 54.0
# reward after ep 619 = 179.0
# reward after ep 624 = -63.0
# reward after ep 629 = 242.0
# reward after ep 634 = 184.0
# reward after ep 639 = 110.0
# reward after ep 644 = 108.0
# reward after ep 649 = -226.0
# Saving Model 650
# reward after ep 654 = 228.0
# reward after ep 659 = 53.0
# reward after ep 664 = 242.0
# reward after ep 669 = 363.0
# reward after ep 674 = 232.0
# reward after ep 679 = 168.0
# reward after ep 684 = 179.0
# reward after ep 689 = -23.0
# reward after ep 694 = 134.0
# reward after ep 699 = 81.0
# Saving Model 700
# reward after ep 704 = 138.0
# reward after ep 709 = 74.0
# reward after ep 714 = 461.0
# reward after ep 719 = -95.0
# reward after ep 724 = 129.0
# reward after ep 729 = 351.0
# reward after ep 734 = 106.0
# reward after ep 739 = 497.0
# reward after ep 744 = 208.0
# reward after ep 749 = -99.0
# Saving Model 750
# reward after ep 754 = 331.0
# reward after ep 759 = 431.0
# reward after ep 764 = 68.0
# reward after ep 769 = 373.0
# reward after ep 774 = 198.0
# reward after ep 779 = 503.0
# reward after ep 784 = 238.0
# reward after ep 789 = -180.0
# reward after ep 794 = -80.0
# reward after ep 799 = 160.0
# Saving Model 800
# reward after ep 804 = 150.0
# reward after ep 809 = -20.0
# reward after ep 814 = 98.0
# reward after ep 819 = -160.0
# reward after ep 824 = 426.0
# reward after ep 829 = 62.0
# reward after ep 834 = 153.0
# reward after ep 839 = 372.0
# reward after ep 844 = 117.0
# reward after ep 849 = 362.0
# Saving Model 850
# reward after ep 854 = 123.0
# reward after ep 859 = 64.0
# reward after ep 864 = 454.0
# reward after ep 869 = 164.0
# reward after ep 874 = 72.0
# reward after ep 879 = 270.0
# reward after ep 884 = 162.0
# reward after ep 889 = 197.0
# reward after ep 894 = 263.0
# reward after ep 899 = 313.0
# Saving Model 900
# reward after ep 904 = 206.0
# reward after ep 909 = -113.0
# reward after ep 914 = 220.0
# reward after ep 919 = 105.0
# reward after ep 924 = 151.0
# reward after ep 929 = -14.0
# reward after ep 934 = 150.0
# reward after ep 939 = 346.0
# reward after ep 944 = 357.0
# reward after ep 949 = 238.0
# Saving Model 950
# reward after ep 954 = 260.0
# reward after ep 959 = 484.0
# reward after ep 964 = 126.0
# reward after ep 969 = 256.0
# reward after ep 974 = 94.0
# reward after ep 979 = 286.0
# reward after ep 984 = 63.0
# reward after ep 989 = -9.0
# reward after ep 994 = 292.0
# reward after ep 999 = 515.0
# Saving Model 1000
# reward after ep 1004 = 220.0
# reward after ep 1009 = 533.0
# reward after ep 1014 = 153.0
# reward after ep 1019 = 434.0
# reward after ep 1024 = 98.0
# reward after ep 1029 = 561.0
# reward after ep 1034 = 199.0
# reward after ep 1039 = 673.0
# reward after ep 1044 = 468.0
# reward after ep 1049 = 606.0
# Saving Model 1050
# reward after ep 1054 = 611.0
# reward after ep 1059 = 450.0
# reward after ep 1064 = 269.0
# reward after ep 1069 = 274.0
# reward after ep 1074 = 124.0
# reward after ep 1079 = 477.0
# reward after ep 1084 = 385.0
# reward after ep 1089 = 255.0
# reward after ep 1094 = 354.0
# reward after ep 1099 = 231.0
# Saving Model 1100
# reward after ep 1104 = 435.0
# reward after ep 1109 = 258.0
# reward after ep 1114 = 422.0
# reward after ep 1119 = 553.0
# reward after ep 1124 = 342.0
# reward after ep 1129 = 475.0
# reward after ep 1134 = 165.0
# reward after ep 1139 = 108.0
# reward after ep 1144 = 418.0
# reward after ep 1149 = 448.0
# Saving Model 1150
# reward after ep 1154 = 85.0
# reward after ep 1159 = 26.0
# reward after ep 1164 = 282.0
# reward after ep 1169 = 495.0
# reward after ep 1174 = 481.0
# reward after ep 1179 = 321.0
# reward after ep 1184 = 523.0
# reward after ep 1189 = 321.0
# reward after ep 1194 = 47.0
# reward after ep 1199 = 274.0
# Saving Model 1200
# reward after ep 1204 = 380.0
# reward after ep 1209 = 621.0
# reward after ep 1214 = 166.0
# reward after ep 1219 = 368.0
# reward after ep 1224 = 383.0
# reward after ep 1229 = 245.0
# reward after ep 1234 = 171.0
# reward after ep 1239 = 558.0
# reward after ep 1244 = 381.0
# reward after ep 1249 = 349.0
# Saving Model 1250
# reward after ep 1254 = 436.0
# reward after ep 1259 = 702.0
# reward after ep 1264 = 134.0
# reward after ep 1269 = 315.0
# reward after ep 1274 = 675.0
# reward after ep 1279 = 377.0
# reward after ep 1284 = 269.0
# reward after ep 1289 = 804.0
# reward after ep 1294 = 524.0
# reward after ep 1299 = 813.0
# Saving Model 1300
# reward after ep 1304 = 666.0
# reward after ep 1309 = 570.0
# reward after ep 1314 = 677.0
# reward after ep 1319 = 648.0
# reward after ep 1324 = 193.0
# reward after ep 1329 = 213.0
# reward after ep 1334 = 772.0
# reward after ep 1339 = 459.0
# reward after ep 1344 = 350.0
# reward after ep 1349 = 162.0
# Saving Model 1350
# reward after ep 1354 = 364.0
# reward after ep 1359 = 541.0
# reward after ep 1364 = 317.0
# reward after ep 1369 = 99.0
# reward after ep 1374 = 517.0
# reward after ep 1379 = 199.0
# reward after ep 1384 = 228.0
# reward after ep 1389 = 674.0
# reward after ep 1394 = 562.0
# reward after ep 1399 = 558.0
# Saving Model 1400
# reward after ep 1404 = 631.0
# reward after ep 1409 = 499.0
# reward after ep 1414 = 460.0
# reward after ep 1419 = 581.0
# reward after ep 1424 = 654.0
# reward after ep 1429 = 519.0
# reward after ep 1434 = 637.0
# reward after ep 1439 = 213.0
# reward after ep 1444 = 639.0
# reward after ep 1449 = 493.0
# Saving Model 1450
# reward after ep 1454 = 732.0
# reward after ep 1459 = 175.0
# reward after ep 1464 = 854.0
# reward after ep 1469 = 760.0
# reward after ep 1474 = 386.0
# reward after ep 1479 = 683.0
# reward after ep 1484 = 482.0
# reward after ep 1489 = 475.0
# reward after ep 1494 = 911.0
# reward after ep 1499 = 650.0
# Saving Model 1500
# reward after ep 1504 = 683.0
# reward after ep 1509 = 566.0
# reward after ep 1514 = 352.0
# reward after ep 1519 = 378.0
# reward after ep 1524 = 918.0
# reward after ep 1529 = 876.0
# reward after ep 1534 = 169.0
# reward after ep 1539 = 799.0
# reward after ep 1544 = 665.0
# reward after ep 1549 = 441.0
# Saving Model 1550
# reward after ep 1554 = 376.0
# reward after ep 1559 = 628.0
# reward after ep 1564 = 318.0
# reward after ep 1569 = 629.0
# reward after ep 1574 = 254.0
# reward after ep 1579 = 535.0
# reward after ep 1584 = 516.0
# reward after ep 1589 = 810.0
# reward after ep 1594 = 662.0
# reward after ep 1599 = 695.0
# Saving Model 1600
# reward after ep 1604 = 576.0
# reward after ep 1609 = 735.0
# reward after ep 1614 = 761.0
# reward after ep 1619 = 326.0
# reward after ep 1624 = 477.0
# reward after ep 1629 = 722.0
# reward after ep 1634 = 409.0
# reward after ep 1639 = 720.0
# reward after ep 1644 = 527.0
# reward after ep 1649 = 777.0
# Saving Model 1650
# reward after ep 1654 = 493.0
# reward after ep 1659 = 94.0
# reward after ep 1664 = 560.0
# reward after ep 1669 = 594.0
# reward after ep 1674 = 504.0
# reward after ep 1679 = 471.0
# reward after ep 1684 = 445.0
# reward after ep 1689 = 596.0
# reward after ep 1694 = 657.0
# reward after ep 1699 = 724.0
# Saving Model 1700
# reward after ep 1704 = 692.0
# reward after ep 1709 = 382.0
# reward after ep 1714 = 463.0
# reward after ep 1719 = 742.0
# reward after ep 1724 = 589.0
# reward after ep 1729 = 603.0
# reward after ep 1734 = 692.0
# reward after ep 1739 = 503.0
# reward after ep 1744 = 432.0
# reward after ep 1749 = 762.0
# Saving Model 1750
# reward after ep 1754 = 705.0
# reward after ep 1759 = 789.0
# reward after ep 1764 = 473.0
# reward after ep 1769 = 335.0
# reward after ep 1774 = 310.0
# reward after ep 1779 = 601.0
# reward after ep 1784 = 692.0
# reward after ep 1789 = 881.0
# reward after ep 1794 = 864.0
# reward after ep 1799 = 320.0
# Saving Model 1800
# reward after ep 1804 = 589.0
# reward after ep 1809 = 440.0
# reward after ep 1814 = 666.0
# reward after ep 1819 = 639.0
# reward after ep 1824 = 614.0
# reward after ep 1829 = 768.0
# reward after ep 1834 = 451.0
# reward after ep 1839 = 448.0
# reward after ep 1844 = 535.0
# reward after ep 1849 = 269.0
# Saving Model 1850
# reward after ep 1854 = 747.0
# reward after ep 1859 = 629.0
# reward after ep 1864 = 514.0
# reward after ep 1869 = 862.0
# reward after ep 1874 = 791.0
# reward after ep 1879 = 513.0
# reward after ep 1884 = 576.0
# reward after ep 1889 = 567.0
# reward after ep 1894 = 745.0
# reward after ep 1899 = 533.0
# Saving Model 1900
# reward after ep 1904 = 745.0
# reward after ep 1909 = 485.0
# reward after ep 1914 = 822.0
# reward after ep 1919 = 693.0
# reward after ep 1924 = 546.0
# reward after ep 1929 = 544.0
# reward after ep 1934 = 594.0
# reward after ep 1939 = 734.0
# reward after ep 1944 = 782.0
# reward after ep 1949 = 625.0
# Saving Model 1950
# reward after ep 1954 = 877.0
# reward after ep 1959 = 198.0
# reward after ep 1964 = 360.0
# reward after ep 1969 = 886.0
# reward after ep 1974 = 528.0
# reward after ep 1979 = 1169.0
# reward after ep 1984 = 844.0
# reward after ep 1989 = 321.0
# reward after ep 1994 = 511.0
# reward after ep 1999 = 792.0
# Saving Model 2000
# reward after ep 2004 = 337.0
# reward after ep 2009 = 421.0
# reward after ep 2014 = 310.0
# reward after ep 2019 = 732.0
# reward after ep 2024 = 644.0
# reward after ep 2029 = 563.0
# reward after ep 2034 = 799.0
# reward after ep 2039 = 702.0
# reward after ep 2044 = 916.0
# reward after ep 2049 = 732.0
# Saving Model 2050
# reward after ep 2054 = 984.0
# reward after ep 2059 = 441.0
# reward after ep 2064 = 489.0
# reward after ep 2069 = 843.0
# reward after ep 2074 = 619.0
# reward after ep 2079 = 1207.0
# reward after ep 2084 = 745.0
# reward after ep 2089 = 402.0
# reward after ep 2094 = 940.0
# reward after ep 2099 = 603.0
# Saving Model 2100
# reward after ep 2104 = 679.0
# reward after ep 2109 = 594.0
# reward after ep 2114 = 792.0
# reward after ep 2119 = 433.0
# reward after ep 2124 = 644.0
# reward after ep 2129 = 571.0
# reward after ep 2134 = 708.0
# reward after ep 2139 = 888.0
# reward after ep 2144 = 725.0
# reward after ep 2149 = 749.0
# Saving Model 2150
# reward after ep 2154 = 555.0
# reward after ep 2159 = 595.0
# reward after ep 2164 = 610.0
# reward after ep 2169 = 891.0
# reward after ep 2174 = 683.0
# reward after ep 2179 = 722.0
# reward after ep 2184 = 920.0
# reward after ep 2189 = 980.0
# reward after ep 2194 = 497.0
# reward after ep 2199 = 814.0
# Saving Model 2200
# reward after ep 2204 = 683.0
# reward after ep 2209 = 975.0
# reward after ep 2214 = 458.0
# reward after ep 2219 = 543.0
# reward after ep 2224 = 695.0
# reward after ep 2229 = 931.0
# reward after ep 2234 = 708.0
# reward after ep 2239 = 584.0
# reward after ep 2244 = 782.0
# reward after ep 2249 = 841.0
# Saving Model 2250
# reward after ep 2254 = 641.0
# reward after ep 2259 = 781.0
# reward after ep 2264 = 742.0
# reward after ep 2269 = 708.0
# reward after ep 2274 = 1033.0
# reward after ep 2279 = 784.0
# reward after ep 2284 = 723.0
# reward after ep 2289 = 804.0
# reward after ep 2294 = 1052.0
# reward after ep 2299 = 720.0
# Saving Model 2300
# reward after ep 2304 = 1017.0
# reward after ep 2309 = 819.0
# reward after ep 2314 = 998.0
# reward after ep 2319 = 680.0
# reward after ep 2324 = 764.0
# reward after ep 2329 = 458.0
# reward after ep 2334 = 987.0
# reward after ep 2339 = 799.0
# reward after ep 2344 = 691.0
# reward after ep 2349 = 747.0
# Saving Model 2350
# reward after ep 2354 = 675.0
# reward after ep 2359 = 577.0
# reward after ep 2364 = 828.0
# reward after ep 2369 = 688.0
# reward after ep 2374 = 791.0
# reward after ep 2379 = 705.0
# reward after ep 2384 = 862.0
# reward after ep 2389 = 686.0
# reward after ep 2394 = 967.0
# reward after ep 2399 = 702.0
# Saving Model 2400
# reward after ep 2404 = 818.0
# reward after ep 2409 = 808.0
# reward after ep 2414 = 819.0
# reward after ep 2419 = 805.0
# reward after ep 2424 = 715.0
# reward after ep 2429 = 648.0
# reward after ep 2434 = 638.0
# reward after ep 2439 = 1025.0
# reward after ep 2444 = 849.0
# reward after ep 2449 = 961.0
# Saving Model 2450
# reward after ep 2454 = 913.0
# reward after ep 2459 = 908.0
# reward after ep 2464 = 639.0
# reward after ep 2469 = 681.0
# reward after ep 2474 = 775.0
# reward after ep 2479 = 691.0
# reward after ep 2484 = 428.0
# reward after ep 2489 = 838.0
# reward after ep 2494 = 652.0
# reward after ep 2499 = 909.0
# Saving Model 2500
# reward after ep 2504 = 591.0
# reward after ep 2509 = 786.0
# reward after ep 2514 = 841.0
# reward after ep 2519 = 805.0
# reward after ep 2524 = 877.0
# reward after ep 2529 = 827.0
# reward after ep 2534 = 553.0
# reward after ep 2539 = 1029.0
# reward after ep 2544 = 852.0
# reward after ep 2549 = 947.0
# Saving Model 2550
# reward after ep 2554 = 866.0
# reward after ep 2559 = 480.0
# reward after ep 2564 = 1048.0
# reward after ep 2569 = 595.0
# reward after ep 2574 = 747.0
# reward after ep 2579 = 1023.0
# reward after ep 2584 = 370.0
# reward after ep 2589 = 881.0
# reward after ep 2594 = 948.0
# reward after ep 2599 = 698.0
# Saving Model 2600
# reward after ep 2604 = 753.0
# reward after ep 2609 = 674.0
# reward after ep 2614 = 781.0
# reward after ep 2619 = 819.0
# reward after ep 2624 = 969.0
# reward after ep 2629 = 765.0
# reward after ep 2634 = 1186.0
# reward after ep 2639 = 1077.0
# reward after ep 2644 = 1025.0
# reward after ep 2649 = 828.0
# Saving Model 2650
# reward after ep 2654 = 952.0
# reward after ep 2659 = 571.0
# reward after ep 2664 = 713.0
# reward after ep 2669 = 684.0
# reward after ep 2674 = 722.0
# reward after ep 2679 = 943.0
# reward after ep 2684 = 463.0
# reward after ep 2689 = 1316.0
# reward after ep 2694 = 813.0
# reward after ep 2699 = 944.0
# Saving Model 2700
# reward after ep 2704 = 864.0
# reward after ep 2709 = 782.0
# reward after ep 2714 = 1060.0
# reward after ep 2719 = 1003.0
# reward after ep 2724 = 438.0
# reward after ep 2729 = 523.0
# reward after ep 2734 = 1065.0
# reward after ep 2739 = 757.0
# reward after ep 2744 = 692.0
# reward after ep 2749 = 1066.0
# Saving Model 2750
# reward after ep 2754 = 844.0
# reward after ep 2759 = 894.0
# reward after ep 2764 = 785.0
# reward after ep 2769 = 625.0
# reward after ep 2774 = 885.0
# reward after ep 2779 = 949.0
# reward after ep 2784 = 494.0
# reward after ep 2789 = 473.0
# reward after ep 2794 = 560.0
# reward after ep 2799 = 1058.0
# Saving Model 2800
# reward after ep 2804 = 787.0
# reward after ep 2809 = 1066.0
# reward after ep 2814 = 1368.0
# reward after ep 2819 = 1215.0
# reward after ep 2824 = 758.0
# reward after ep 2829 = 727.0
# reward after ep 2834 = 749.0
# reward after ep 2839 = 823.0
# reward after ep 2844 = 1125.0
# reward after ep 2849 = 886.0
# Saving Model 2850
# reward after ep 2854 = 640.0
# reward after ep 2859 = 681.0
# reward after ep 2864 = 1047.0
# reward after ep 2869 = 504.0
# reward after ep 2874 = 864.0
# reward after ep 2879 = 841.0
# reward after ep 2884 = 854.0
# reward after ep 2889 = 964.0
# reward after ep 2894 = 677.0
# reward after ep 2899 = 895.0
# Saving Model 2900
# reward after ep 2904 = 642.0
# reward after ep 2909 = 724.0
# reward after ep 2914 = 760.0
# reward after ep 2919 = 483.0
# reward after ep 2924 = 850.0
# reward after ep 2929 = 873.0
# reward after ep 2934 = 897.0
# reward after ep 2939 = 630.0
# reward after ep 2944 = 804.0
# reward after ep 2949 = 951.0
# Saving Model 2950
# reward after ep 2954 = 997.0
# reward after ep 2959 = 782.0
# reward after ep 2964 = 974.0
# reward after ep 2969 = 899.0
# reward after ep 2974 = 686.0
# reward after ep 2979 = 1035.0
# reward after ep 2984 = 902.0
# reward after ep 2989 = 941.0
# reward after ep 2994 = 1016.0
# reward after ep 2999 = 971.0
# Saving Model 3000
# reward after ep 3004 = 969.0
# reward after ep 3009 = 1336.0
# reward after ep 3014 = 760.0
# reward after ep 3019 = 605.0
# reward after ep 3024 = 708.0
# reward after ep 3029 = 848.0
# reward after ep 3034 = 930.0
# reward after ep 3039 = 767.0
# reward after ep 3044 = 958.0
# reward after ep 3049 = 840.0
# Saving Model 3050
# reward after ep 3054 = 567.0
# reward after ep 3059 = 696.0
# reward after ep 3064 = 922.0
# reward after ep 3069 = 554.0
# reward after ep 3074 = 675.0
# reward after ep 3079 = 976.0
# reward after ep 3084 = 888.0
# reward after ep 3089 = 677.0
# reward after ep 3094 = 945.0
# reward after ep 3099 = 461.0
# Saving Model 3100
# reward after ep 3104 = 953.0
# reward after ep 3109 = 1123.0
# reward after ep 3114 = 1042.0
# reward after ep 3119 = 831.0
# reward after ep 3124 = 819.0
# reward after ep 3129 = 692.0
# reward after ep 3134 = 984.0
# reward after ep 3139 = 890.0
# reward after ep 3144 = 1432.0
# reward after ep 3149 = 544.0
# Saving Model 3150
# reward after ep 3154 = 830.0
# reward after ep 3159 = 949.0
# reward after ep 3164 = 938.0
# reward after ep 3169 = 688.0
# reward after ep 3174 = 813.0
# reward after ep 3179 = 907.0
# reward after ep 3184 = 594.0
# reward after ep 3189 = 774.0
# reward after ep 3194 = 670.0
# reward after ep 3199 = 880.0
# Saving Model 3200
# reward after ep 3204 = 822.0
# reward after ep 3209 = 930.0
# reward after ep 3214 = 1147.0
# reward after ep 3219 = 1107.0
# reward after ep 3224 = 1105.0
# reward after ep 3229 = 970.0
# reward after ep 3234 = 953.0
# reward after ep 3239 = 852.0
# reward after ep 3244 = 861.0
# reward after ep 3249 = 877.0
# Saving Model 3250
# reward after ep 3254 = 758.0
# reward after ep 3259 = 342.0
# reward after ep 3264 = 737.0
# reward after ep 3269 = 597.0
# reward after ep 3274 = 836.0
# reward after ep 3279 = 677.0
# reward after ep 3284 = 764.0
# reward after ep 3289 = 829.0
# reward after ep 3294 = 1098.0
# reward after ep 3299 = 994.0
# Saving Model 3300
# reward after ep 3304 = 1025.0
# reward after ep 3309 = 670.0
# reward after ep 3314 = 780.0
# reward after ep 3319 = 534.0
# reward after ep 3324 = 673.0
# reward after ep 3329 = 704.0
# reward after ep 3334 = 954.0
# reward after ep 3339 = 840.0
# reward after ep 3344 = 1178.0
# reward after ep 3349 = 814.0
# Saving Model 3350
# reward after ep 3354 = 758.0
# reward after ep 3359 = 964.0
# reward after ep 3364 = 583.0
# reward after ep 3369 = 639.0
# reward after ep 3374 = 832.0
# reward after ep 3379 = 511.0
# reward after ep 3384 = 975.0
# reward after ep 3389 = 589.0
# reward after ep 3394 = 808.0
# reward after ep 3399 = 1034.0
# Saving Model 3400
# reward after ep 3404 = 1214.0
# reward after ep 3409 = 936.0
# reward after ep 3414 = 1053.0
# reward after ep 3419 = 855.0
# reward after ep 3424 = 1020.0
# reward after ep 3429 = 868.0
# reward after ep 3434 = 456.0
# reward after ep 3439 = 706.0
# reward after ep 3444 = 666.0
# reward after ep 3449 = 967.0
# Saving Model 3450
# reward after ep 3454 = 801.0
# reward after ep 3459 = 967.0
# reward after ep 3464 = 967.0
# reward after ep 3469 = 445.0
# reward after ep 3474 = 817.0
# reward after ep 3479 = 1148.0
# reward after ep 3484 = 878.0
# reward after ep 3489 = 1311.0
# reward after ep 3494 = 1013.0
# reward after ep 3499 = 905.0
# Saving Model 3500
# reward after ep 3504 = 1262.0
# reward after ep 3509 = 885.0
# reward after ep 3514 = 1058.0
# reward after ep 3519 = 1102.0
# reward after ep 3524 = 1031.0
# reward after ep 3529 = 639.0
# reward after ep 3534 = 1091.0
# reward after ep 3539 = 855.0
# reward after ep 3544 = 751.0
# reward after ep 3549 = 1012.0
# Saving Model 3550
# reward after ep 3554 = 767.0
# reward after ep 3559 = 881.0
# reward after ep 3564 = 844.0
# reward after ep 3569 = 1060.0
# reward after ep 3574 = 946.0
# reward after ep 3579 = 971.0
# reward after ep 3584 = 737.0
# reward after ep 3589 = 885.0
# reward after ep 3594 = 1444.0
# reward after ep 3599 = 961.0
# Saving Model 3600
# reward after ep 3604 = 1149.0
# reward after ep 3609 = 881.0
# reward after ep 3614 = 714.0
# reward after ep 3619 = 706.0
# reward after ep 3624 = 760.0
# reward after ep 3629 = 1133.0
# reward after ep 3634 = 1016.0
# reward after ep 3639 = 821.0
# reward after ep 3644 = 648.0
# reward after ep 3649 = 1263.0
# Saving Model 3650
# reward after ep 3654 = 1230.0
# reward after ep 3659 = 764.0
# reward after ep 3664 = 706.0
# reward after ep 3669 = 982.0
# reward after ep 3674 = 1035.0
# reward after ep 3679 = 801.0
# reward after ep 3684 = 1133.0
# reward after ep 3689 = 995.0
# reward after ep 3694 = 864.0
# reward after ep 3699 = 994.0
# Saving Model 3700
# reward after ep 3704 = 918.0
# reward after ep 3709 = 815.0
# reward after ep 3714 = 534.0
# reward after ep 3719 = 954.0
# reward after ep 3724 = 935.0
# reward after ep 3729 = 1004.0
# reward after ep 3734 = 859.0
# reward after ep 3739 = 1059.0
# reward after ep 3744 = 1026.0
# reward after ep 3749 = 1075.0
# Saving Model 3750
# reward after ep 3754 = 1023.0
# reward after ep 3759 = 997.0
# reward after ep 3764 = 1150.0
# reward after ep 3769 = 783.0
# reward after ep 3774 = 900.0
# reward after ep 3779 = 898.0
# reward after ep 3784 = 971.0
# reward after ep 3789 = 882.0
# reward after ep 3794 = 1102.0
# reward after ep 3799 = 814.0
# Saving Model 3800
# reward after ep 3804 = 724.0
# reward after ep 3809 = 607.0
# reward after ep 3814 = 1217.0
# reward after ep 3819 = 1133.0
# reward after ep 3824 = 814.0
# reward after ep 3829 = 868.0
# reward after ep 3834 = 985.0
# reward after ep 3839 = 864.0
# reward after ep 3844 = 1201.0
# reward after ep 3849 = 812.0
# Saving Model 3850
# reward after ep 3854 = 1354.0
# reward after ep 3859 = 936.0
# reward after ep 3864 = 684.0
# reward after ep 3869 = 778.0
# reward after ep 3874 = 522.0
# reward after ep 3879 = 675.0
# reward after ep 3884 = 991.0
# reward after ep 3889 = 552.0
# reward after ep 3894 = 967.0
# reward after ep 3899 = 630.0
# Saving Model 3900
# reward after ep 3904 = 781.0
# reward after ep 3909 = 951.0
# reward after ep 3914 = 521.0
# reward after ep 3919 = 976.0
# reward after ep 3924 = 938.0
# reward after ep 3929 = 1141.0
# reward after ep 3934 = 770.0
# reward after ep 3939 = 1062.0
# reward after ep 3944 = 990.0
# reward after ep 3949 = 1152.0
# Saving Model 3950
# reward after ep 3954 = 1017.0
# reward after ep 3959 = 913.0
# reward after ep 3964 = 832.0
# reward after ep 3969 = 1123.0
# reward after ep 3974 = 827.0
# reward after ep 3979 = 584.0
# reward after ep 3984 = 711.0
# reward after ep 3989 = 996.0
# reward after ep 3994 = 1133.0
# reward after ep 3999 = 987.0
# Saving Model 4000
# reward after ep 4004 = 610.0
# reward after ep 4009 = 414.0
# reward after ep 4014 = 647.0
# reward after ep 4019 = 734.0
# reward after ep 4024 = 931.0
# reward after ep 4029 = 855.0
# reward after ep 4034 = 976.0
# reward after ep 4039 = 760.0
# reward after ep 4044 = 1162.0
# reward after ep 4049 = 951.0
# Saving Model 4050
# reward after ep 4054 = 1162.0
# reward after ep 4059 = 957.0
# reward after ep 4064 = 698.0
# reward after ep 4069 = 1044.0
# reward after ep 4074 = 875.0
# reward after ep 4079 = 1044.0
# reward after ep 4084 = 858.0
# reward after ep 4089 = 949.0
# reward after ep 4094 = 1044.0
# reward after ep 4099 = 1011.0
# Saving Model 4100
# reward after ep 4104 = 890.0
# reward after ep 4109 = 1001.0
# reward after ep 4114 = 944.0
# reward after ep 4119 = 875.0
# reward after ep 4124 = 958.0
# reward after ep 4129 = 992.0
# reward after ep 4134 = 629.0
# reward after ep 4139 = 1283.0
# reward after ep 4144 = 986.0
# reward after ep 4149 = 691.0
# Saving Model 4150
# reward after ep 4154 = 1048.0
# reward after ep 4159 = 519.0
# reward after ep 4164 = 771.0
# reward after ep 4169 = 929.0
# reward after ep 4174 = 1178.0
# reward after ep 4179 = 949.0
# reward after ep 4184 = 994.0
# reward after ep 4189 = 756.0
# reward after ep 4194 = 860.0
# reward after ep 4199 = 1402.0
# Saving Model 4200
# reward after ep 4204 = 957.0
# reward after ep 4209 = 498.0
# reward after ep 4214 = 861.0
# reward after ep 4219 = 729.0
# reward after ep 4224 = 609.0
# reward after ep 4229 = 898.0
# reward after ep 4234 = 708.0
# reward after ep 4239 = 1171.0
# reward after ep 4244 = 991.0
# reward after ep 4249 = 787.0
# Saving Model 4250
# reward after ep 4254 = 868.0
# reward after ep 4259 = 751.0
# reward after ep 4264 = 1184.0
# reward after ep 4269 = 703.0
# reward after ep 4274 = 1119.0
# reward after ep 4279 = 898.0
# reward after ep 4284 = 720.0
# reward after ep 4289 = 797.0
# reward after ep 4294 = 454.0
# reward after ep 4299 = 895.0
# Saving Model 4300
# reward after ep 4304 = 896.0
# reward after ep 4309 = 1097.0
# reward after ep 4314 = 1184.0
# reward after ep 4319 = 990.0
# reward after ep 4324 = 1219.0
# reward after ep 4329 = 756.0
# reward after ep 4334 = 818.0
# reward after ep 4339 = 742.0
# reward after ep 4344 = 1050.0
# reward after ep 4349 = 680.0
# Saving Model 4350
# reward after ep 4354 = 1033.0
# reward after ep 4359 = 1191.0
# reward after ep 4364 = 1228.0
# reward after ep 4369 = 810.0
# reward after ep 4374 = 1006.0
# reward after ep 4379 = 1017.0
# reward after ep 4384 = 1144.0
# reward after ep 4389 = 567.0
# reward after ep 4394 = 1027.0
# reward after ep 4399 = 871.0
# Saving Model 4400
# reward after ep 4404 = 901.0
# reward after ep 4409 = 808.0
# reward after ep 4414 = 976.0
# reward after ep 4419 = 988.0
# reward after ep 4424 = 963.0
# reward after ep 4429 = 1002.0
# reward after ep 4434 = 652.0
# reward after ep 4439 = 1051.0
# reward after ep 4444 = 588.0
# reward after ep 4449 = 1038.0
# Saving Model 4450
# reward after ep 4454 = 799.0
# reward after ep 4459 = 651.0
# reward after ep 4464 = 1089.0
# reward after ep 4469 = 947.0
# reward after ep 4474 = 837.0
# reward after ep 4479 = 1051.0
# reward after ep 4484 = 653.0
# reward after ep 4489 = 1190.0
# reward after ep 4494 = 611.0
# reward after ep 4499 = 1048.0
# Saving Model 4500
# reward after ep 4504 = 747.0
# reward after ep 4509 = 1142.0
# reward after ep 4514 = 742.0
# reward after ep 4519 = 1124.0
# reward after ep 4524 = 851.0
# reward after ep 4529 = 805.0
# reward after ep 4534 = 1017.0
# reward after ep 4539 = 665.0
# reward after ep 4544 = 882.0
# reward after ep 4549 = 732.0
# Saving Model 4550
# reward after ep 4554 = 627.0
# reward after ep 4559 = 817.0
# reward after ep 4564 = 814.0
# reward after ep 4569 = 765.0
# reward after ep 4574 = 1134.0
# reward after ep 4579 = 804.0
# reward after ep 4584 = 637.0
# reward after ep 4589 = 1119.0
# reward after ep 4594 = 1084.0
# reward after ep 4599 = 819.0
# Saving Model 4600
# reward after ep 4604 = 854.0
# reward after ep 4609 = 1102.0
# reward after ep 4614 = 1195.0
# reward after ep 4619 = 837.0
# reward after ep 4624 = 691.0
# reward after ep 4629 = 633.0
# reward after ep 4634 = 1183.0
# reward after ep 4639 = 702.0
# reward after ep 4644 = 1128.0
# reward after ep 4649 = 692.0
# Saving Model 4650
# reward after ep 4654 = 700.0
# reward after ep 4659 = 834.0
# reward after ep 4664 = 549.0
# reward after ep 4669 = 633.0
# reward after ep 4674 = 964.0
# reward after ep 4679 = 909.0
# reward after ep 4684 = 868.0
# reward after ep 4689 = 796.0
# reward after ep 4694 = 588.0
# reward after ep 4699 = 1089.0
# Saving Model 4700
# reward after ep 4704 = 498.0
# reward after ep 4709 = 971.0
# reward after ep 4714 = 795.0
# reward after ep 4719 = 1033.0
# reward after ep 4724 = 949.0
# reward after ep 4729 = 791.0
# reward after ep 4734 = 1129.0
# reward after ep 4739 = 383.0
# reward after ep 4744 = 1006.0
# reward after ep 4749 = 901.0
# Saving Model 4750
# reward after ep 4754 = 1007.0
# reward after ep 4759 = 737.0
# reward after ep 4764 = 1079.0
# reward after ep 4769 = 979.0
# reward after ep 4774 = 909.0
# reward after ep 4779 = 768.0
# reward after ep 4784 = 1069.0
# reward after ep 4789 = 1025.0
# reward after ep 4794 = 1138.0
# reward after ep 4799 = 1186.0
# Saving Model 4800
# reward after ep 4804 = 1232.0
# reward after ep 4809 = 1092.0
# reward after ep 4814 = 1056.0
# reward after ep 4819 = 1159.0
# reward after ep 4824 = 773.0
# reward after ep 4829 = 841.0
# reward after ep 4834 = 779.0
# reward after ep 4839 = 899.0
# reward after ep 4844 = 1200.0
# reward after ep 4849 = 929.0
# Saving Model 4850
# reward after ep 4854 = 1121.0
# reward after ep 4859 = 1122.0
# reward after ep 4864 = 922.0
# reward after ep 4869 = 998.0
# reward after ep 4874 = 778.0
# reward after ep 4879 = 1015.0
# reward after ep 4884 = 925.0
# reward after ep 4889 = 418.0
# reward after ep 4894 = 1053.0
# reward after ep 4899 = 1266.0
# Saving Model 4900
# reward after ep 4904 = 1065.0
# reward after ep 4909 = 1205.0
# reward after ep 4914 = 1037.0
# reward after ep 4919 = 769.0
# reward after ep 4924 = 974.0
# reward after ep 4929 = 1117.0
# reward after ep 4934 = 499.0
# reward after ep 4939 = 1137.0
# reward after ep 4944 = 1177.0
# reward after ep 4949 = 1137.0
# Saving Model 4950
# reward after ep 4954 = 831.0
# reward after ep 4959 = 951.0
# reward after ep 4964 = 979.0
# reward after ep 4969 = 1213.0
# reward after ep 4974 = 794.0
# reward after ep 4979 = 1135.0
# reward after ep 4984 = 1048.0
# reward after ep 4989 = 1053.0
# reward after ep 4994 = 1044.0
# reward after ep 4999 = 1001.0
# Saving Model 5000
# reward after ep 5004 = 927.0
# reward after ep 5009 = 989.0
# reward after ep 5014 = 1035.0
# reward after ep 5019 = 1327.0
# reward after ep 5024 = 1083.0
# reward after ep 5029 = 1012.0
# reward after ep 5034 = 1001.0
# reward after ep 5039 = 944.0
# reward after ep 5044 = 668.0
# reward after ep 5049 = 1134.0
# Saving Model 5050
# reward after ep 5054 = 804.0
# reward after ep 5059 = 820.0
# reward after ep 5064 = 1065.0
# reward after ep 5069 = 1164.0
# reward after ep 5074 = 665.0
# reward after ep 5079 = 1096.0
# reward after ep 5084 = 558.0
# reward after ep 5089 = 629.0
# reward after ep 5094 = 1087.0
# reward after ep 5099 = 932.0
# Saving Model 5100
# reward after ep 5104 = 1122.0
# reward after ep 5109 = 571.0
# reward after ep 5114 = 1169.0
# reward after ep 5119 = 772.0
# reward after ep 5124 = 1032.0
# reward after ep 5129 = 585.0
# reward after ep 5134 = 650.0
# reward after ep 5139 = 1034.0
# reward after ep 5144 = 1093.0
# reward after ep 5149 = 1078.0
# Saving Model 5150
# reward after ep 5154 = 1024.0
# reward after ep 5159 = 1025.0
# reward after ep 5164 = 1075.0
# reward after ep 5169 = 993.0
# reward after ep 5174 = 882.0
# reward after ep 5179 = 1037.0
# reward after ep 5184 = 1281.0
# reward after ep 5189 = 989.0
# reward after ep 5194 = 883.0
# reward after ep 5199 = 810.0
# Saving Model 5200
# reward after ep 5204 = 605.0
# reward after ep 5209 = 938.0
# reward after ep 5214 = 774.0
# reward after ep 5219 = 731.0
# reward after ep 5224 = 882.0
# reward after ep 5229 = 1055.0
# reward after ep 5234 = 1047.0
# reward after ep 5239 = 1169.0
# reward after ep 5244 = 911.0
# reward after ep 5249 = 369.0
# Saving Model 5250
# reward after ep 5254 = 882.0
# reward after ep 5259 = 926.0
# reward after ep 5264 = 609.0
# reward after ep 5269 = 892.0
# reward after ep 5274 = 1087.0
# reward after ep 5279 = 1012.0
# reward after ep 5284 = 1416.0
# reward after ep 5289 = 885.0
# reward after ep 5294 = 921.0
# reward after ep 5299 = 878.0
# Saving Model 5300
# reward after ep 5304 = 976.0
# reward after ep 5309 = 1134.0
# reward after ep 5314 = 837.0
# reward after ep 5319 = 1062.0
# reward after ep 5324 = 835.0
# reward after ep 5329 = 1206.0
# reward after ep 5334 = 1192.0
# reward after ep 5339 = 876.0
# reward after ep 5344 = 864.0
# reward after ep 5349 = 1188.0
# Saving Model 5350
# reward after ep 5354 = 721.0
# reward after ep 5359 = 1178.0
# reward after ep 5364 = 1085.0
# reward after ep 5369 = 683.0
# reward after ep 5374 = 1106.0
# reward after ep 5379 = 508.0
# reward after ep 5384 = 1088.0
# reward after ep 5389 = 918.0
# reward after ep 5394 = 762.0
# reward after ep 5399 = 1065.0
# Saving Model 5400
# reward after ep 5404 = 1032.0
# reward after ep 5409 = 992.0
# reward after ep 5414 = 993.0
# reward after ep 5419 = 1026.0
# reward after ep 5424 = 817.0
# reward after ep 5429 = 1128.0
# reward after ep 5434 = 1061.0
# reward after ep 5439 = 589.0
# reward after ep 5444 = 798.0
# reward after ep 5449 = 1064.0
# Saving Model 5450
# reward after ep 5454 = 809.0
# reward after ep 5459 = 981.0
# reward after ep 5464 = 520.0
# reward after ep 5469 = 1030.0
# reward after ep 5474 = 1027.0
# reward after ep 5479 = 729.0
# reward after ep 5484 = 693.0
# reward after ep 5489 = 814.0
# reward after ep 5494 = 931.0
# reward after ep 5499 = 1336.0
# Saving Model 5500
# reward after ep 5504 = 827.0
# reward after ep 5509 = 1100.0
# reward after ep 5514 = 1223.0
# reward after ep 5519 = 893.0
# reward after ep 5524 = 276.0
# reward after ep 5529 = 931.0
# reward after ep 5534 = 678.0
# reward after ep 5539 = 1015.0
# reward after ep 5544 = 1065.0
# reward after ep 5549 = 1285.0
# Saving Model 5550
# reward after ep 5554 = 220.0
# reward after ep 5559 = 810.0
# reward after ep 5564 = 876.0
# reward after ep 5569 = 733.0
# reward after ep 5574 = 877.0
# reward after ep 5579 = 922.0
# reward after ep 5584 = 729.0
# reward after ep 5589 = 627.0
# reward after ep 5594 = 554.0
# reward after ep 5599 = 832.0
# Saving Model 5600
# reward after ep 5604 = 654.0
# reward after ep 5609 = 800.0
# reward after ep 5614 = 1133.0
# reward after ep 5619 = 566.0
# reward after ep 5624 = 450.0
# reward after ep 5629 = 742.0
# reward after ep 5634 = 1113.0
# reward after ep 5639 = 832.0
# reward after ep 5644 = 1051.0
# reward after ep 5649 = 1188.0
# Saving Model 5650
# reward after ep 5654 = 770.0
# reward after ep 5659 = 853.0
# reward after ep 5664 = 836.0
# reward after ep 5669 = 792.0
# reward after ep 5674 = 722.0
# reward after ep 5679 = 1053.0
# reward after ep 5684 = 1088.0
# reward after ep 5689 = 731.0
# reward after ep 5694 = 1336.0
# reward after ep 5699 = 919.0
# Saving Model 5700
# reward after ep 5704 = 809.0
# reward after ep 5709 = 621.0
# reward after ep 5714 = 1171.0
# reward after ep 5719 = 695.0
# reward after ep 5724 = 697.0
# reward after ep 5729 = 891.0
# reward after ep 5734 = 503.0
# reward after ep 5739 = 835.0
# reward after ep 5744 = 836.0
# reward after ep 5749 = 1038.0
# Saving Model 5750
# reward after ep 5754 = 846.0
# reward after ep 5759 = 900.0
# reward after ep 5764 = 711.0
# reward after ep 5769 = 936.0
# reward after ep 5774 = 823.0
# reward after ep 5779 = 138.0
# reward after ep 5784 = 651.0
# reward after ep 5789 = 884.0
# reward after ep 5794 = 841.0
# reward after ep 5799 = 980.0
# Saving Model 5800
# reward after ep 5804 = 741.0
# reward after ep 5809 = 931.0
# reward after ep 5814 = 970.0
# reward after ep 5819 = 1152.0
# reward after ep 5824 = 910.0
# reward after ep 5829 = 1087.0
# reward after ep 5834 = 630.0
# reward after ep 5839 = 653.0
# reward after ep 5844 = 1083.0
# reward after ep 5849 = 1047.0
# Saving Model 5850
# reward after ep 5854 = 1065.0
# reward after ep 5859 = 864.0
# reward after ep 5864 = 1117.0
# reward after ep 5869 = 958.0
# reward after ep 5874 = 916.0
# reward after ep 5879 = 958.0
# reward after ep 5884 = 946.0
# reward after ep 5889 = 956.0
# reward after ep 5894 = 665.0
# reward after ep 5899 = 997.0
# Saving Model 5900
# reward after ep 5904 = 1000.0
# reward after ep 5909 = 832.0
# reward after ep 5914 = 767.0
# reward after ep 5919 = 945.0
# reward after ep 5924 = 697.0
# reward after ep 5929 = 822.0
# reward after ep 5934 = 1177.0
# reward after ep 5939 = 718.0
# reward after ep 5944 = 977.0
# reward after ep 5949 = 832.0
# Saving Model 5950
# reward after ep 5954 = 690.0
# reward after ep 5959 = 1152.0
# reward after ep 5964 = 562.0
# reward after ep 5969 = 476.0
# reward after ep 5974 = 895.0
# reward after ep 5979 = 1015.0
# reward after ep 5984 = 1012.0
# reward after ep 5989 = 1097.0
# reward after ep 5994 = 1080.0
# reward after ep 5999 = 1097.0
# Saving Model 6000
# reward after ep 6004 = 866.0
# reward after ep 6009 = 505.0
# reward after ep 6014 = 1026.0
# reward after ep 6019 = 616.0
# reward after ep 6024 = 1012.0
# reward after ep 6029 = 1012.0
# reward after ep 6034 = 746.0
# reward after ep 6039 = 1134.0
# reward after ep 6044 = 1002.0
# reward after ep 6049 = 652.0
# Saving Model 6050
# reward after ep 6054 = 411.0
# reward after ep 6059 = 942.0
# reward after ep 6064 = 923.0
# reward after ep 6069 = 1026.0
# reward after ep 6074 = 966.0
# reward after ep 6079 = 577.0
# reward after ep 6084 = 747.0
# reward after ep 6089 = 877.0
# reward after ep 6094 = 1102.0
# reward after ep 6099 = 651.0
# Saving Model 6100
# reward after ep 6104 = 826.0
# reward after ep 6109 = 773.0
# reward after ep 6114 = 466.0
# reward after ep 6119 = 445.0
# reward after ep 6124 = 679.0
# reward after ep 6129 = 1010.0
# reward after ep 6134 = 1107.0
# reward after ep 6139 = 1121.0
# reward after ep 6144 = 680.0
# reward after ep 6149 = 1114.0
# Saving Model 6150
# reward after ep 6154 = 899.0
# reward after ep 6159 = 895.0
# reward after ep 6164 = 1016.0
# reward after ep 6169 = 783.0
# reward after ep 6174 = 599.0
# reward after ep 6179 = 751.0
# reward after ep 6184 = 749.0
# reward after ep 6189 = 909.0
# reward after ep 6194 = 921.0
# reward after ep 6199 = 769.0
# Saving Model 6200
# reward after ep 6204 = 920.0
# reward after ep 6209 = 929.0
# reward after ep 6214 = 918.0
# reward after ep 6219 = 612.0
# reward after ep 6224 = 857.0
# reward after ep 6229 = 972.0
# reward after ep 6234 = 1146.0
# reward after ep 6239 = 857.0
# reward after ep 6244 = 717.0
# reward after ep 6249 = 1231.0
# Saving Model 6250
# reward after ep 6254 = 1164.0
# reward after ep 6259 = 890.0
# reward after ep 6264 = 1101.0
# reward after ep 6269 = 957.0
# reward after ep 6274 = 882.0
# reward after ep 6279 = 890.0
# reward after ep 6284 = 940.0
# reward after ep 6289 = 901.0
# reward after ep 6294 = 1022.0
# reward after ep 6299 = -75.0
# Saving Model 6300
# reward after ep 6304 = 424.0
# reward after ep 6309 = 534.0
# reward after ep 6314 = 679.0
# reward after ep 6319 = 990.0
# reward after ep 6324 = 908.0
# reward after ep 6329 = 656.0
# reward after ep 6334 = 1009.0
# reward after ep 6339 = 515.0
# reward after ep 6344 = 1044.0
# reward after ep 6349 = 972.0
# Saving Model 6350
# reward after ep 6354 = 710.0
# reward after ep 6359 = 731.0
# reward after ep 6364 = 567.0
# reward after ep 6369 = 865.0
# reward after ep 6374 = 412.0
# reward after ep 6379 = 422.0
# reward after ep 6384 = 733.0
# reward after ep 6389 = 908.0
# reward after ep 6394 = 666.0
# reward after ep 6399 = 916.0
# Saving Model 6400
# reward after ep 6404 = 967.0
# reward after ep 6409 = 982.0
# reward after ep 6414 = 799.0
# reward after ep 6419 = 1096.0
# reward after ep 6424 = 639.0
# reward after ep 6429 = 733.0
# reward after ep 6434 = 701.0
# reward after ep 6439 = 577.0
# reward after ep 6444 = 731.0
# reward after ep 6449 = 706.0
# Saving Model 6450
# reward after ep 6454 = 776.0
# reward after ep 6459 = 477.0
# reward after ep 6464 = 831.0
# reward after ep 6469 = 897.0
# reward after ep 6474 = 490.0
# reward after ep 6479 = 736.0
# reward after ep 6484 = 818.0
# reward after ep 6489 = 616.0
# reward after ep 6494 = 355.0
# reward after ep 6499 = 779.0
# Saving Model 6500
# reward after ep 6504 = 668.0
# reward after ep 6509 = 1048.0
# reward after ep 6514 = 1037.0
# reward after ep 6519 = 774.0
# reward after ep 6524 = 981.0
# reward after ep 6529 = 961.0
# reward after ep 6534 = 801.0
# reward after ep 6539 = 830.0
# reward after ep 6544 = 846.0
# reward after ep 6549 = 873.0
# Saving Model 6550
# reward after ep 6554 = 547.0
# reward after ep 6559 = 934.0
# reward after ep 6564 = 771.0
# reward after ep 6569 = 641.0
# reward after ep 6574 = 981.0
# reward after ep 6579 = 602.0
# reward after ep 6584 = 985.0
# reward after ep 6589 = 966.0
# reward after ep 6594 = 567.0
# reward after ep 6599 = 473.0
# Saving Model 6600
# reward after ep 6604 = 426.0
# reward after ep 6609 = 738.0
# reward after ep 6614 = 835.0
# reward after ep 6619 = 808.0
# reward after ep 6624 = 1017.0
# reward after ep 6629 = 819.0
# reward after ep 6634 = 752.0
# reward after ep 6639 = 855.0
# reward after ep 6644 = 1103.0
# reward after ep 6649 = 747.0
# Saving Model 6650
# reward after ep 6654 = 735.0
# reward after ep 6659 = 828.0
# reward after ep 6664 = 1036.0
# reward after ep 6669 = 808.0
# reward after ep 6674 = 885.0
# reward after ep 6679 = 782.0
# reward after ep 6684 = 1026.0
# reward after ep 6689 = 686.0
# reward after ep 6694 = 810.0
# reward after ep 6699 = 1172.0
# Saving Model 6700
# reward after ep 6704 = 948.0
# reward after ep 6709 = 691.0
# reward after ep 6714 = 1147.0
# reward after ep 6719 = 723.0
# reward after ep 6724 = 787.0
# reward after ep 6729 = 753.0
# reward after ep 6734 = 707.0
# reward after ep 6739 = 966.0
# reward after ep 6744 = 840.0
# reward after ep 6749 = 764.0
# Saving Model 6750
# reward after ep 6754 = 792.0
# reward after ep 6759 = 648.0
# reward after ep 6764 = 816.0
# reward after ep 6769 = 801.0
# reward after ep 6774 = 702.0
# reward after ep 6779 = 673.0
# reward after ep 6784 = 1098.0
# reward after ep 6789 = 740.0
# reward after ep 6794 = 822.0
# reward after ep 6799 = 906.0
# Saving Model 6800
# reward after ep 6804 = 791.0
# reward after ep 6809 = 666.0
# reward after ep 6814 = 1057.0
# reward after ep 6819 = 933.0
# reward after ep 6824 = 1108.0
# reward after ep 6829 = 468.0
# reward after ep 6834 = 676.0
# reward after ep 6839 = 677.0
# reward after ep 6844 = 754.0
# reward after ep 6849 = 664.0
# Saving Model 6850
# reward after ep 6854 = 845.0
# reward after ep 6859 = 673.0
# reward after ep 6864 = 565.0
# reward after ep 6869 = 911.0
# reward after ep 6874 = 716.0
# reward after ep 6879 = 1033.0
# reward after ep 6884 = 922.0
# reward after ep 6889 = 769.0
# reward after ep 6894 = 1178.0
# reward after ep 6899 = 1102.0
# Saving Model 6900
# reward after ep 6904 = 697.0
# reward after ep 6909 = 621.0
# reward after ep 6914 = 730.0
# reward after ep 6919 = 1015.0
# reward after ep 6924 = 961.0
# reward after ep 6929 = 945.0
# reward after ep 6934 = 828.0
# reward after ep 6939 = 629.0
# reward after ep 6944 = 884.0
# reward after ep 6949 = 819.0
# Saving Model 6950
# reward after ep 6954 = 639.0
# reward after ep 6959 = 508.0
# reward after ep 6964 = 816.0
# reward after ep 6969 = 628.0
# reward after ep 6974 = 552.0
# reward after ep 6979 = 332.0
# reward after ep 6984 = 345.0
# reward after ep 6989 = 632.0
# reward after ep 6994 = 489.0
# reward after ep 6999 = 703.0
# Saving Model 7000
# reward after ep 7004 = 575.0
# reward after ep 7009 = 506.0
# reward after ep 7014 = 636.0
# reward after ep 7019 = 483.0
# reward after ep 7024 = 783.0
# reward after ep 7029 = 659.0
# reward after ep 7034 = 695.0
# reward after ep 7039 = 477.0
# reward after ep 7044 = 513.0
# reward after ep 7049 = 501.0
# Saving Model 7050
# reward after ep 7054 = 570.0
# reward after ep 7059 = 922.0
# reward after ep 7064 = 873.0
# reward after ep 7069 = 774.0
# reward after ep 7074 = 759.0
# reward after ep 7079 = 452.0
# reward after ep 7084 = 560.0
# reward after ep 7089 = 756.0
# reward after ep 7094 = 747.0
# reward after ep 7099 = 934.0
# Saving Model 7100
# reward after ep 7104 = 610.0
# reward after ep 7109 = 784.0
# reward after ep 7114 = 953.0
# reward after ep 7119 = 524.0
# reward after ep 7124 = 777.0
# reward after ep 7129 = 526.0
# reward after ep 7134 = 909.0
# reward after ep 7139 = 1006.0
# reward after ep 7144 = 693.0
# reward after ep 7149 = 728.0
# Saving Model 7150
# reward after ep 7154 = 976.0
# reward after ep 7159 = 804.0
# reward after ep 7164 = 814.0
# reward after ep 7169 = 875.0
# reward after ep 7174 = 882.0
# reward after ep 7179 = 651.0
# reward after ep 7184 = 1113.0
# reward after ep 7189 = 486.0
# reward after ep 7194 = 766.0
# reward after ep 7199 = 679.0
# Saving Model 7200
# reward after ep 7204 = 594.0
# reward after ep 7209 = 544.0
# reward after ep 7214 = 1123.0
# reward after ep 7219 = 743.0
# reward after ep 7224 = 680.0
# reward after ep 7229 = 612.0
# reward after ep 7234 = 541.0
# reward after ep 7239 = 1025.0
# reward after ep 7244 = 881.0
# reward after ep 7249 = 1165.0
# Saving Model 7250
# reward after ep 7254 = 1190.0
# reward after ep 7259 = 985.0
# reward after ep 7264 = 1104.0
# reward after ep 7269 = 763.0
# reward after ep 7274 = 837.0
# reward after ep 7279 = 444.0
# reward after ep 7284 = 729.0
# reward after ep 7289 = 857.0
# reward after ep 7294 = 858.0
# reward after ep 7299 = 615.0
# Saving Model 7300
# reward after ep 7304 = 844.0
# reward after ep 7309 = 1085.0
# reward after ep 7314 = 422.0
# reward after ep 7319 = 697.0
# reward after ep 7324 = 881.0
# reward after ep 7329 = 1015.0
# reward after ep 7334 = 783.0
# reward after ep 7339 = 764.0
# reward after ep 7344 = 1062.0
# reward after ep 7349 = 639.0
# Saving Model 7350
# reward after ep 7354 = 1026.0
# reward after ep 7359 = 801.0
# reward after ep 7364 = 772.0
# reward after ep 7369 = 985.0
# reward after ep 7374 = 734.0
# reward after ep 7379 = 657.0
# reward after ep 7384 = 1179.0
# reward after ep 7389 = 1134.0
# reward after ep 7394 = 727.0
# reward after ep 7399 = 898.0
# Saving Model 7400
# reward after ep 7404 = 837.0
# reward after ep 7409 = 873.0
# reward after ep 7414 = 832.0
# reward after ep 7419 = 864.0
# reward after ep 7424 = 1141.0
# reward after ep 7429 = 1060.0
# reward after ep 7434 = 799.0
# reward after ep 7439 = 782.0
# reward after ep 7444 = 767.0
# reward after ep 7449 = 986.0
# Saving Model 7450
# reward after ep 7454 = 1075.0
# reward after ep 7459 = 1104.0
# reward after ep 7464 = 773.0
# reward after ep 7469 = 1084.0
# reward after ep 7474 = 702.0
# reward after ep 7479 = 1196.0
# reward after ep 7484 = 597.0
# reward after ep 7489 = 937.0
# reward after ep 7494 = 929.0
# reward after ep 7499 = 610.0
# Saving Model 7500
# reward after ep 7504 = 837.0
# reward after ep 7509 = 1084.0
# reward after ep 7514 = 965.0
# reward after ep 7519 = 560.0
# reward after ep 7524 = 751.0
# reward after ep 7529 = 829.0
# reward after ep 7534 = 808.0
# reward after ep 7539 = 730.0
# reward after ep 7544 = 920.0
# reward after ep 7549 = 863.0
# Saving Model 7550
# reward after ep 7554 = 924.0
# reward after ep 7559 = 406.0
# reward after ep 7564 = 958.0
# reward after ep 7569 = 183.0
# reward after ep 7574 = 300.0
# reward after ep 7579 = 641.0
# reward after ep 7584 = 747.0
# reward after ep 7589 = 710.0
# reward after ep 7594 = 971.0
# reward after ep 7599 = 521.0
# Saving Model 7600
# reward after ep 7604 = 957.0
# reward after ep 7609 = 639.0
# reward after ep 7614 = 705.0
# reward after ep 7619 = 722.0
# reward after ep 7624 = 648.0
# reward after ep 7629 = 790.0
# reward after ep 7634 = 1024.0
# reward after ep 7639 = 688.0
# reward after ep 7644 = 916.0
# reward after ep 7649 = 603.0
# Saving Model 7650
# reward after ep 7654 = 592.0
# reward after ep 7659 = 824.0
# reward after ep 7664 = 393.0
# reward after ep 7669 = 617.0
# reward after ep 7674 = 620.0
# reward after ep 7679 = 638.0
# reward after ep 7684 = 670.0
# reward after ep 7689 = 783.0
# reward after ep 7694 = 671.0
# reward after ep 7699 = 668.0
# Saving Model 7700
# reward after ep 7704 = 912.0
# reward after ep 7709 = 683.0
# reward after ep 7714 = 837.0
# reward after ep 7719 = 322.0
# reward after ep 7724 = 560.0
# reward after ep 7729 = 747.0
# reward after ep 7734 = 399.0
# reward after ep 7739 = 657.0
# reward after ep 7744 = 531.0
# reward after ep 7749 = 793.0
# Saving Model 7750
# reward after ep 7754 = 682.0
# reward after ep 7759 = 691.0
# reward after ep 7764 = 493.0
# reward after ep 7769 = 580.0
# reward after ep 7774 = 631.0
# reward after ep 7779 = 656.0
# reward after ep 7784 = 967.0
# ...
# reward after ep 9479 = 416.0
# reward after ep 9484 = 472.0
# reward after ep 9489 = 615.0
# reward after ep 9494 = -47.0
# reward after ep 9499 = 730.0
# Saving Model 9500
# reward after ep 9504 = 542.0
# reward after ep 9509 = 686.0
# reward after ep 9514 = 717.0
# reward after ep 9519 = 832.0
# reward after ep 9524 = 276.0
# reward after ep 9529 = 543.0
# reward after ep 9534 = 778.0
# reward after ep 9539 = 569.0
# reward after ep 9544 = 349.0
# reward after ep 9549 = 531.0
# Saving Model 9550
# reward after ep 9554 = 611.0
# reward after ep 9559 = 501.0
# reward after ep 9564 = 795.0
# reward after ep 9569 = 357.0
# reward after ep 9574 = 289.0
# reward after ep 9579 = 380.0
# reward after ep 9584 = 580.0
# reward after ep 9589 = 180.0
# reward after ep 9594 = 543.0
# reward after ep 9599 = 697.0
# Saving Model 9600
# reward after ep 9604 = 129.0
# reward after ep 9609 = 555.0
# reward after ep 9614 = 467.0
# reward after ep 9619 = 440.0
# reward after ep 9624 = 261.0
# reward after ep 9629 = 760.0
# reward after ep 9634 = 641.0
# reward after ep 9639 = 710.0
# reward after ep 9644 = 1015.0
# reward after ep 9649 = 618.0
# Saving Model 9650
# reward after ep 9654 = 540.0
# reward after ep 9659 = 484.0
# reward after ep 9664 = 476.0
# reward after ep 9669 = 580.0
# reward after ep 9674 = 455.0
# reward after ep 9679 = 661.0
# reward after ep 9684 = 449.0
# reward after ep 9689 = 741.0
# reward after ep 9694 = 350.0
# reward after ep 9699 = 427.0
# Saving Model 9700
# reward after ep 9704 = 345.0
# reward after ep 9709 = 216.0
# reward after ep 9714 = 790.0
# reward after ep 9719 = 321.0
# reward after ep 9724 = 486.0
# reward after ep 9729 = 268.0
# reward after ep 9734 = 635.0
# reward after ep 9739 = 566.0
# reward after ep 9744 = 319.0
# reward after ep 9749 = 805.0
# Saving Model 9750
# reward after ep 9754 = 116.0
# reward after ep 9759 = 622.0
# reward after ep 9764 = 418.0
# reward after ep 9769 = 386.0
# reward after ep 9774 = 832.0
# reward after ep 9779 = 434.0
# reward after ep 9784 = 460.0
# reward after ep 9789 = 274.0
# reward after ep 9794 = 208.0
# reward after ep 9799 = 279.0
# Saving Model 9800
# reward after ep 9804 = 715.0
# reward after ep 9809 = 144.0
# reward after ep 9814 = 585.0
# reward after ep 9819 = 343.0
# reward after ep 9824 = 665.0
# reward after ep 9829 = 695.0
# reward after ep 9834 = 450.0
# reward after ep 9839 = 494.0
# reward after ep 9844 = 191.0
# reward after ep 9849 = 542.0
# Saving Model 9850
# reward after ep 9854 = 298.0
# reward after ep 9859 = 393.0
# reward after ep 9864 = 277.0
# reward after ep 9869 = 531.0
# reward after ep 9874 = 666.0
# reward after ep 9879 = 396.0
# reward after ep 9884 = 244.0
# reward after ep 9889 = 490.0
# reward after ep 9894 = 835.0
# reward after ep 9899 = 286.0
# Saving Model 9900
# reward after ep 9904 = 683.0
# reward after ep 9909 = 731.0
# reward after ep 9914 = 624.0
# reward after ep 9919 = 787.0
# reward after ep 9924 = 277.0
# reward after ep 9929 = 508.0
# reward after ep 9934 = 632.0
# reward after ep 9939 = 521.0
# reward after ep 9944 = 409.0
# reward after ep 9949 = 481.0
# Saving Model 9950
# reward after ep 9954 = 504.0
# reward after ep 9959 = 490.0
# reward after ep 9964 = 581.0
# reward after ep 9969 = 156.0
# reward after ep 9974 = 432.0
# reward after ep 9979 = 928.0
# reward after ep 9984 = 551.0
# reward after ep 9989 = 363.0
# reward after ep 9994 = 568.0
# reward after ep 9999 = 346.0
# Saving Model 10000
# reward after ep 10004 = -36.0
# reward after ep 10009 = 243.0
# reward after ep 10014 = 675.0
# reward after ep 10019 = 573.0
# reward after ep 10024 = 336.0
# reward after ep 10029 = 262.0
# reward after ep 10034 = 516.0
# reward after ep 10039 = 473.0
# reward after ep 10044 = 365.0
# reward after ep 10049 = 481.0
# Saving Model 10050
# reward after ep 10054 = 423.0
# reward after ep 10059 = 551.0
# reward after ep 10064 = 461.0
# reward after ep 10069 = 307.0
# reward after ep 10074 = 526.0
# reward after ep 10079 = 430.0
# reward after ep 10084 = 594.0
# reward after ep 10089 = 927.0
# reward after ep 10094 = 379.0
# reward after ep 10099 = 141.0
# Saving Model 10100
# reward after ep 10104 = 319.0
# reward after ep 10109 = 611.0
# reward after ep 10114 = 533.0
# reward after ep 10119 = 383.0
# reward after ep 10124 = 604.0
# reward after ep 10129 = 530.0
# reward after ep 10134 = 136.0
# reward after ep 10139 = 129.0
# reward after ep 10144 = 505.0
# reward after ep 10149 = 570.0
# Saving Model 10150
# reward after ep 10154 = 250.0
# reward after ep 10159 = 288.0
# reward after ep 10164 = 468.0
# reward after ep 10169 = 596.0
# reward after ep 10174 = 783.0
# reward after ep 10179 = 408.0
# reward after ep 10184 = 312.0
# reward after ep 10189 = 49.0
# reward after ep 10194 = 502.0
# reward after ep 10199 = 551.0
# Saving Model 10200
# reward after ep 10204 = 465.0
# reward after ep 10209 = 747.0
# reward after ep 10214 = 715.0
# reward after ep 10219 = 701.0
# reward after ep 10224 = 476.0
# reward after ep 10229 = 709.0
# reward after ep 10234 = 623.0
# reward after ep 10239 = 537.0
# reward after ep 10244 = 500.0
# reward after ep 10249 = 504.0
# Saving Model 10250
# reward after ep 10254 = 444.0
# reward after ep 10259 = 381.0
# reward after ep 10264 = 364.0
# reward after ep 10269 = 384.0
# reward after ep 10274 = 188.0
# reward after ep 10279 = 318.0
# reward after ep 10284 = 612.0
# reward after ep 10289 = 570.0
# reward after ep 10294 = 368.0
# reward after ep 10299 = 253.0
# Saving Model 10300
# reward after ep 10304 = 542.0
# reward after ep 10309 = 531.0
# reward after ep 10314 = 670.0
# reward after ep 10319 = 404.0
# reward after ep 10324 = 150.0
# reward after ep 10329 = 346.0
# reward after ep 10334 = 412.0
# reward after ep 10339 = 387.0
# reward after ep 10344 = -251.0
# reward after ep 10349 = 335.0
# Saving Model 10350
# reward after ep 10354 = 400.0
# reward after ep 10359 = 546.0
# reward after ep 10364 = 481.0
# reward after ep 10369 = 389.0
# reward after ep 10374 = 625.0
# reward after ep 10379 = 466.0
# reward after ep 10384 = 667.0
# reward after ep 10389 = 606.0
# reward after ep 10394 = 672.0
# reward after ep 10399 = 496.0
# Saving Model 10400
# reward after ep 10404 = 537.0
# reward after ep 10409 = 687.0
# reward after ep 10414 = 606.0
# reward after ep 10419 = 597.0
# reward after ep 10424 = 187.0
# reward after ep 10429 = 472.0
# reward after ep 10434 = 533.0
# reward after ep 10439 = 585.0
# reward after ep 10444 = 489.0
# reward after ep 10449 = 556.0
# Saving Model 10450
# reward after ep 10454 = 457.0
# reward after ep 10459 = 45.0
# reward after ep 10464 = 234.0
# reward after ep 10469 = 308.0
# reward after ep 10474 = 404.0
# reward after ep 10479 = 570.0
# reward after ep 10484 = 673.0
# reward after ep 10489 = 607.0
# reward after ep 10494 = 701.0
# reward after ep 10499 = 546.0
# Saving Model 10500
# reward after ep 10504 = 375.0
# reward after ep 10509 = 390.0
# reward after ep 10514 = 423.0
# reward after ep 10519 = 431.0
# reward after ep 10524 = 410.0
# reward after ep 10529 = 618.0
# reward after ep 10534 = 472.0
# reward after ep 10539 = 269.0
# reward after ep 10544 = 561.0
# reward after ep 10549 = 630.0
# Saving Model 10550
# reward after ep 10554 = 787.0
# reward after ep 10559 = 647.0
# reward after ep 10564 = 398.0
# reward after ep 10569 = 337.0
# reward after ep 10574 = 255.0
# reward after ep 10579 = 607.0
# reward after ep 10584 = 346.0
# reward after ep 10589 = 842.0
# reward after ep 10594 = 351.0
# reward after ep 10599 = 341.0
# Saving Model 10600
# reward after ep 10604 = 325.0
# reward after ep 10609 = 418.0
# reward after ep 10614 = 913.0
# reward after ep 10619 = 476.0
# reward after ep 10624 = 612.0
# reward after ep 10629 = 588.0
# reward after ep 10634 = 489.0
# reward after ep 10639 = 533.0
# reward after ep 10644 = 606.0
# reward after ep 10649 = 459.0
# Saving Model 10650
# reward after ep 10654 = 454.0
# reward after ep 10659 = 528.0
# reward after ep 10664 = 382.0
# reward after ep 10669 = 538.0
# reward after ep 10674 = 431.0
# reward after ep 10679 = 565.0
# reward after ep 10684 = 917.0
# reward after ep 10689 = 542.0
# reward after ep 10694 = 636.0
# reward after ep 10699 = 422.0
# Saving Model 10700
# reward after ep 10704 = 580.0
# reward after ep 10709 = 515.0
# reward after ep 10714 = 607.0
# reward after ep 10719 = 621.0
# reward after ep 10724 = 534.0
# reward after ep 10729 = 791.0
# reward after ep 10734 = 728.0
# reward after ep 10739 = 535.0
# reward after ep 10744 = 660.0
# reward after ep 10749 = 571.0
# Saving Model 10750
# reward after ep 10754 = 546.0
# reward after ep 10759 = 326.0
# reward after ep 10764 = 492.0
# reward after ep 10769 = 465.0
# reward after ep 10774 = 600.0
# reward after ep 10779 = 585.0
# reward after ep 10784 = 762.0
# reward after ep 10789 = 561.0
# reward after ep 10794 = 720.0
# reward after ep 10799 = 636.0
# Saving Model 10800
# reward after ep 10804 = 490.0
# reward after ep 10809 = 381.0
# reward after ep 10814 = 729.0
# reward after ep 10819 = 481.0
# reward after ep 10824 = 486.0
# reward after ep 10829 = 166.0
# reward after ep 10834 = 441.0
# reward after ep 10839 = 522.0
# reward after ep 10844 = 501.0
# reward after ep 10849 = 112.0
# Saving Model 10850
# reward after ep 10854 = 476.0
# reward after ep 10859 = 623.0
# reward after ep 10864 = 742.0
# reward after ep 10869 = 510.0
# reward after ep 10874 = 648.0
# reward after ep 10879 = 696.0
# reward after ep 10884 = 521.0
# reward after ep 10889 = 544.0
# reward after ep 10894 = 306.0
# reward after ep 10899 = 520.0
# Saving Model 10900
# reward after ep 10904 = 418.0
# reward after ep 10909 = 403.0
# reward after ep 10914 = 679.0
# reward after ep 10919 = 715.0
# reward after ep 10924 = 528.0
# reward after ep 10929 = 760.0
# reward after ep 10934 = 815.0
# reward after ep 10939 = 672.0
# reward after ep 10944 = 553.0
# reward after ep 10949 = 727.0
# Saving Model 10950
# reward after ep 10954 = 853.0
# reward after ep 10959 = 624.0
# reward after ep 10964 = 557.0
# reward after ep 10969 = 350.0
# reward after ep 10974 = 229.0
# reward after ep 10979 = 600.0
# reward after ep 10984 = 418.0
# reward after ep 10989 = 529.0
# reward after ep 10994 = 750.0
# reward after ep 10999 = 345.0
# Saving Model 11000
# reward after ep 11004 = 428.0
# reward after ep 11009 = 537.0
# reward after ep 11014 = 747.0
# reward after ep 11019 = 633.0
# reward after ep 11024 = 697.0
# reward after ep 11029 = 369.0
# reward after ep 11034 = 617.0
# reward after ep 11039 = 670.0
# reward after ep 11044 = 480.0
# reward after ep 11049 = 557.0
# Saving Model 11050
# reward after ep 11054 = 790.0
# reward after ep 11059 = 544.0
# reward after ep 11064 = 477.0
# reward after ep 11069 = 684.0
# reward after ep 11074 = 854.0
# reward after ep 11079 = 594.0
# reward after ep 11084 = 639.0
# reward after ep 11089 = 418.0
# reward after ep 11094 = 711.0
# reward after ep 11099 = 474.0
# Saving Model 11100
# reward after ep 11104 = 399.0
# reward after ep 11109 = 643.0
# reward after ep 11114 = 578.0
# reward after ep 11119 = 565.0
# reward after ep 11124 = 742.0
# reward after ep 11129 = 273.0
# reward after ep 11134 = 629.0
# reward after ep 11139 = 672.0
# reward after ep 11144 = 426.0
# reward after ep 11149 = 508.0
# Saving Model 11150
# reward after ep 11154 = 757.0
# reward after ep 11159 = 670.0
# reward after ep 11164 = 493.0
# reward after ep 11169 = 544.0
# reward after ep 11174 = 1018.0
# reward after ep 11179 = 553.0
# reward after ep 11184 = 810.0
# reward after ep 11189 = 176.0
# reward after ep 11194 = 576.0
# reward after ep 11199 = 678.0
# Saving Model 11200
# reward after ep 11204 = 510.0
# reward after ep 11209 = 757.0
# reward after ep 11214 = 395.0
# reward after ep 11219 = 526.0
# reward after ep 11224 = 484.0
# reward after ep 11229 = 775.0
# reward after ep 11234 = 765.0
# reward after ep 11239 = 504.0
# reward after ep 11244 = 746.0
# reward after ep 11249 = 523.0
# Saving Model 11250
# reward after ep 11254 = 651.0
# reward after ep 11259 = 391.0
# reward after ep 11264 = 812.0
# reward after ep 11269 = 389.0
# reward after ep 11274 = 730.0
# reward after ep 11279 = 211.0
# reward after ep 11284 = 236.0
# reward after ep 11289 = 625.0
# reward after ep 11294 = 953.0
# reward after ep 11299 = 659.0
# Saving Model 11300
# reward after ep 11304 = 510.0
# reward after ep 11309 = 736.0
# reward after ep 11314 = 651.0
# reward after ep 11319 = 360.0
# reward after ep 11324 = 477.0
# reward after ep 11329 = 515.0
# reward after ep 11334 = 646.0
# reward after ep 11339 = 546.0
# reward after ep 11344 = 500.0
# reward after ep 11349 = 535.0
# Saving Model 11350
# reward after ep 11354 = 645.0
# reward after ep 11359 = 627.0
# reward after ep 11364 = 359.0
# reward after ep 11369 = 579.0
# reward after ep 11374 = 594.0
# reward after ep 11379 = 620.0
# reward after ep 11384 = 574.0
# reward after ep 11389 = 448.0
# reward after ep 11394 = 407.0
# reward after ep 11399 = 445.0
# Saving Model 11400
# reward after ep 11404 = 250.0
# reward after ep 11409 = 571.0
# reward after ep 11414 = 142.0
# reward after ep 11419 = 567.0
# reward after ep 11424 = 540.0
# reward after ep 11429 = 579.0
# reward after ep 11434 = 444.0
# reward after ep 11439 = 377.0
# reward after ep 11444 = 396.0
# reward after ep 11449 = 663.0
# Saving Model 11450
# reward after ep 11454 = 490.0
# reward after ep 11459 = 252.0
# reward after ep 11464 = 916.0
# reward after ep 11469 = 859.0
# reward after ep 11474 = 639.0
# reward after ep 11479 = 414.0
# reward after ep 11484 = 495.0
# reward after ep 11489 = 412.0
# reward after ep 11494 = 628.0
# reward after ep 11499 = 658.0
# Saving Model 11500
# reward after ep 11504 = 903.0
# reward after ep 11509 = 569.0
# reward after ep 11514 = 491.0
# reward after ep 11519 = 505.0
# reward after ep 11524 = 327.0
# reward after ep 11529 = 543.0
# reward after ep 11534 = 912.0
# reward after ep 11539 = 744.0
# reward after ep 11544 = 615.0
# reward after ep 11549 = 530.0
# Saving Model 11550
# reward after ep 11554 = 512.0
# reward after ep 11559 = 706.0
# reward after ep 11564 = 604.0
# reward after ep 11569 = 262.0
# reward after ep 11574 = 580.0
# reward after ep 11579 = 421.0
# reward after ep 11584 = 633.0
# reward after ep 11589 = 612.0
# reward after ep 11594 = 645.0
# reward after ep 11599 = 588.0
# Saving Model 11600
# reward after ep 11604 = 521.0
# reward after ep 11609 = 555.0
# reward after ep 11614 = 789.0
# reward after ep 11619 = 422.0
# reward after ep 11624 = 675.0
# reward after ep 11629 = 718.0
# reward after ep 11634 = 989.0
# reward after ep 11639 = 530.0
# reward after ep 11644 = 651.0
# reward after ep 11649 = 630.0
# Saving Model 11650
# reward after ep 11654 = 367.0
# reward after ep 11659 = 513.0
# reward after ep 11664 = 622.0
# reward after ep 11669 = 485.0
# reward after ep 11674 = 469.0
# reward after ep 11679 = 855.0
# reward after ep 11684 = 724.0
# reward after ep 11689 = 482.0
# reward after ep 11694 = 787.0
# reward after ep 11699 = 876.0
# Saving Model 11700
# reward after ep 11704 = 537.0
# reward after ep 11709 = 432.0
# reward after ep 11714 = 454.0
# reward after ep 11719 = 759.0
# reward after ep 11724 = 436.0
# reward after ep 11729 = 764.0
# reward after ep 11734 = 647.0
# reward after ep 11739 = 598.0
# reward after ep 11744 = 651.0
# reward after ep 11749 = 507.0
# Saving Model 11750
# reward after ep 11754 = 777.0
# reward after ep 11759 = 495.0
# reward after ep 11764 = 350.0
# reward after ep 11769 = 427.0
# reward after ep 11774 = 577.0
# reward after ep 11779 = 399.0
# reward after ep 11784 = 777.0
# reward after ep 11789 = 142.0
# reward after ep 11794 = 713.0
# reward after ep 11799 = 706.0
# Saving Model 11800
# reward after ep 11804 = 693.0
# reward after ep 11809 = 565.0
# reward after ep 11814 = 688.0
# reward after ep 11819 = 525.0
# reward after ep 11824 = 269.0
# reward after ep 11829 = 480.0
# reward after ep 11834 = 443.0
# reward after ep 11839 = 805.0
# reward after ep 11844 = 677.0
# reward after ep 11849 = 369.0
# Saving Model 11850
# reward after ep 11854 = 368.0
# reward after ep 11859 = 659.0
# reward after ep 11864 = 414.0
# reward after ep 11869 = 658.0
# reward after ep 11874 = 715.0
# reward after ep 11879 = 616.0
# reward after ep 11884 = 336.0
# reward after ep 11889 = 153.0
# reward after ep 11894 = 479.0
# reward after ep 11899 = 601.0
# Saving Model 11900
# reward after ep 11904 = 628.0
# reward after ep 11909 = 319.0
# reward after ep 11914 = 496.0
# reward after ep 11919 = 773.0
# reward after ep 11924 = 690.0
# reward after ep 11929 = 766.0
# reward after ep 11934 = 493.0
# reward after ep 11939 = 480.0
# reward after ep 11944 = 1002.0
# reward after ep 11949 = 595.0
# Saving Model 11950
# reward after ep 11954 = 742.0
# reward after ep 11959 = 270.0
# reward after ep 11964 = 685.0
# reward after ep 11969 = 632.0
# reward after ep 11974 = 494.0
# reward after ep 11979 = 576.0
# reward after ep 11984 = 756.0
# reward after ep 11989 = 566.0
# reward after ep 11994 = 517.0
# reward after ep 11999 = 702.0

# %%
score_tracked_sample = [rewards_per_episode[i] for i in range(len(rewards_per_episode)) if (i % 4 == 0)]

# %%
plt.figure(0, figsize=(16,7))
plt.title('Rewards per episode')
xaxis = np.asarray(range(0, len(score_tracked_sample)))
plt.plot(xaxis,np.asarray(score_tracked_sample))
plt.show()

# %% [markdown]
# ### Tracking Convergence

# %%
print("Average reward of last 8000 episodes is {0}".format(np.max(rewards_per_episode[-8000:])))
# Out:
# Average reward of last 8000 episodes is 1509.0

# %%
with open('saved_pickle_files/rewards_per_episode.pkl', 'rb') as f:
    rewards_per_episode = pickle.load(f)

plt.plot(list(range(len(rewards_per_episode))), rewards_per_episode)
plt.xlabel("episode number")
plt.ylabel("reward per episode")
print(len(rewards_per_episode))

# save plots in saved_plots/ directory
plt.savefig('rewards.png')

print("Average reward of last 8000 episodes is {0}".format(np.mean(rewards_per_episode[-8000:])))
# Out:
# 11951
# Average reward of last 8000 episodes is 718.06225

# %%
with open('saved_pickle_files/States_tracked.pkl', 'rb') as f:
    States_track = pickle.load(f)

# %%
plt.figure(0, figsize=(16,7))
plt.subplot(241)
plt.title('state=(15,mon) action=12')
xaxis = np.asarray(range(0, len(States_track[(1,9,1)][(1,2)])))
plt.plot(xaxis,np.asarray(States_track[(1,9,1)][(1,2)]))

plt.subplot(242)
plt.title('state=(15,mon) action=12')
xaxis = np.asarray(range(0, len(States_track[(1,20,5)][(2,4)])))
plt.plot(xaxis,np.asarray(States_track[(1,20,5)][(2,4)]))

plt.subplot(243)
plt.title('state=(15,mon) action=12')
xaxis = np.asarray(range(0, len(States_track[(1,11,3)][(1,3)])))
plt.plot(xaxis,np.asarray(States_track[(1,11,3)][(1,3)]))

plt.subplot(244)
plt.title('state=(15,mon) action=12')
xaxis = np.asarray(range(0, len(States_track[(4,10,5)][(3,1)])))
plt.plot(xaxis,np.asarray(States_track[(4,10,5)][(3,1)]))

plt.subplot(245)
plt.title('state=(15,mon) action=12')
xaxis = np.asarray(range(0, len(States_track[(3,13,0)][(3,1)])))
plt.plot(xaxis,np.asarray(States_track[(3,13,0)][(3,1)]))

plt.subplot(246)
plt.title('state=(15,mon) action=12')
xaxis = np.asarray(range(0, len(States_track[(0,9,6)][(1,3)])))
plt.plot(xaxis,np.asarray(States_track[(0,9,6)][(1,3)]))

# %%
state_tracked_sample = [agent.special_states_tracked[i] for i in range(len(agent.special_states_tracked)) if agent.special_states_tracked[i] < 1000]

# %%
# Tracked a special state
plt.figure(0, figsize=(16,7))
plt.title('Q_value for state [0,0,0]  action (0,2)')
xaxis = np.asarray(range(0, len(agent.special_states_tracked)))
plt.semilogy(xaxis,np.asarray(agent.special_states_tracked))
plt.show()

# %%
for key, value in States_track.items():
    for k,v in value.items():
        print(len(v))
# Out:
# 1056
# 918
# 1499
# 268
# 1220
# 1005

# %% [markdown]
# #### Epsilon-decay sample function

# %% [markdown]
# <div class="alert alert-block alert-info">
# Try building a similar epsilon-decay function for your model.
# </div>

# %%
time = np.arange(0,100)
epsilon = []
for i in range(0,3000):
    epsilon.append(0 + (1 - 0) * np.exp(-0.0009*i))
   # epsilon.append(np.random.rand())
print(epsilon)

# %%
plt.plot(time, epsilon)
plt.show()
